# %%
import sys
sys.path.append('../.')
import data_perp
import numpy as np
import matplotlib.pylab as plt
import cv2

# %%
dataset_path = "/home/max/ieos/small_obj/vid_pred/data/simple_detr_dataset/train_1_frame_v2"
dataset_path_stroika = "/home/max/ieos/small_obj/vid_pred/data/stroika/train"
r_size = (224,224)
dataset = data_perp.DETRDataset(dataset_path_stroika, norm=False, size=[])
resizer = data_perp.Resizer(r_size)

# %%
sample, coords = dataset[122]

# %%
img = np.concatenate([sample, sample, sample], axis=-1)
for c in coords['bbox']:
    print(c)
    img = cv2.circle(img, (int(c[0]), int(c[1])), 3, (255,0,0), -1)
plt.imshow(img, cmap='gray');
# Out:
# tensor([224.0000, 112.5000,  12.0000,  29.0000])
# tensor([190.5000, 122.5000,  11.0000,  13.0000])
# tensor([120., 207.,  10.,  18.])
# tensor([ 89.5000, 213.0000,  11.0000,  28.0000])
# tensor([276.5000,  85.5000,   5.0000,  23.0000])
# tensor([284.5000,  83.5000,   5.0000,  21.0000])
# tensor([554.5000, 116.0000,  11.0000,  20.0000])
# tensor([243.5000,  64.0000,   7.0000,  10.0000])
# tensor([273.0000,  58.5000,   8.0000,   7.0000])
# tensor([297.5000,  57.5000,   5.0000,   9.0000])

# %%
from torchvision.transforms import v2
import torch

# %%
sample_transforms = v2.Compose([
        v2.ToImage(),
        v2.ToDtype(torch.float32, scale=True),
        v2.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
        ])

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
t_img = sample_transforms(img)

# %%
t_img.max()
# Out:
# tensor(1.)

# %%
t_img.min()
# Out:
# tensor(-1.)

# %%
img.shape
# Out:
# (224, 224, 3)

# %%
t_img.shape
# Out:
# torch.Size([3, 224, 224])

# %%
sample.shape
# Out:
# (224, 224, 1)

# %%
t_sample = sample_transforms(sample)
t_sample.shape
# Out:
# torch.Size([3, 224, 224])

# %%
t_sample.min()
# Out:
# tensor(-0.9686)

# %%
t_sample.max()
# Out:
# tensor(0.8745)

# %%
cv2.fillPoly()

# %%
data_path = "/home/max/ieos/small_obj/vid_pred/data/simple_detr_dataset/train_1_frame_v2/window_vid_1_7997_0.pickle"
sample, coords = dataset._from_pickle(data_path)

# %%
plt.imshow(sample, cmap='gray');
print(coords)

# %%
plt.imshow(sample, cmap='gray');
print(coords)
# Out:
# [[324.0, 237.5, 28.0, 35.0]]
